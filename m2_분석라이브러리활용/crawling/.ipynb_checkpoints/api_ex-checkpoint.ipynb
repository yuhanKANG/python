# %% [markdown]
# ## 네이버 검색 API 서비스

# %% [markdown]
# ####  블로그

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "Jj0OXLwhiIThZiPeurcm"
client_secret = "Z34Uu4mSeJ"

query = urllib.parse.quote(input('검색어를 입력해주세요 : '))
url = "https://openapi.naver.com/v1/search/blog?query=" + query # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + query # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색어를 입력해주세요 : 빅데이터
# {
# 	"lastBuildDate":"Thu, 28 Jul 2022 17:12:49 +0900",
# 	"total":1144839,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>빅데이터<\/b>전문가 준비를 위한 체계적인 방법",
# 			"link":"https:\/\/blog.naver.com\/nam8853nam?Redirect=Log&logNo=222802704648",
# 			"description":"그 중에서도 주목해 볼만한 분야가 바로 ‘<b>빅데이터<\/b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... ",
# 			"bloggername":"율맘 스토리",
# 			"bloggerlink":"https:\/\/blog.naver.com\/nam8853nam",
# 			"postdate":"20220707"
# 		},
# 		{
# 			"title":"<b>빅데이터<\/b>분석기사 실기 준비를 위한 학습루틴",
# 			"link":"https:\/\/blog.naver.com\/parkrapp?Redirect=Log&logNo=222753783578",
# 			"description":"안녕하세요, 오늘은 제가 도전한 <b>빅데이터<\/b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... <b>빅데이터<\/b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... ",
# 			"bloggername":"황금빛 쭈롱월드",
# 			"bloggerlink":"https:\/\/blog.naver.com\/parkrapp",
# 			"postdate":"20220531"
# 		},
# 		{
# ...

# %%
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

xml = response_body.decode('utf-8') # 위에서 바디를 불러왔었음
bs = BeautifulSoup(xml, 'lxml')
bs.get_text()
# Out:
# '{\n\t"lastBuildDate":"Thu, 28 Jul 2022 17:12:49 +0900",\n\t"total":1144839,\n\t"start":1,\n\t"display":10,\n\t"items":[\n\t\t{\n\t\t\t"title":"빅데이터<\\/b>전문가 준비를 위한 체계적인 방법",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/nam8853nam?Redirect=Log&logNo=222802704648",\n\t\t\t"description":"그 중에서도 주목해 볼만한 분야가 바로 ‘빅데이터<\\/b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... ",\n\t\t\t"bloggername":"율맘 스토리",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/nam8853nam",\n\t\t\t"postdate":"20220707"\n\t\t},\n\t\t{\n\t\t\t"title":"빅데이터<\\/b>분석기사 실기 준비를 위한 학습루틴",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/parkrapp?Redirect=Log&logNo=222753783578",\n\t\t\t"description":"안녕하세요, 오늘은 제가 도전한 빅데이터<\\/b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... 빅데이터<\\/b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... ",\n\t\t\t"bloggername":"황금빛 쭈롱월드",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/parkrapp",\n\t\t\t"postdate":"20220531"\n\t\t},\n\t\t{\n\t\t\t"title":"
# ...

# %% [markdown]
# #### Q. 네이버 웹문서에서 빅데이터에 대한 데이터를 가져와서 데이터프레임으로 출력하세요.(api 가이드 참조)

# %%
import urllib.request
import requests
from bs4 import BeautifulSoup
url = 'https://openapi.naver.com/v1/search/webkr.xml?query='+urllib.parse.quote(input('검색어 : '))
# url = "https://openapi.naver.com/v1/search/blog?query="
client_id = "Jj0OXLwhiIThZiPeurcm"
client_secret = "Z34Uu4mSeJ"

response = requests.get(url)
# bs = BeautifulSoup(response, 'html.parser')
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    a = response_body.decode('utf-8')
    print(a)
else:
    print("Error Code:" + rescode)

import warnings
warnings.filterwarnings('ignore')
import pandas as pd
# df = pd.read_json(response_body.decode('utf-8'))
# df
# Out:
# 검색어 : 빅데이터
# ...

# %%
import pandas as pd
df.loc[ind] = [title,link]

df = pd.DataFrame(columns=['title','link'])
df


bs = BeautifulSoup(response, 'html.parser')
bs2.find('div', id = 'dic_area').text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [110], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df.loc[ind] = [title,link]
#       4 df = pd.DataFrame(columns=['title','link'])
#       5 df
#
# NameError: name 'title' is not defined

# %% [markdown]
# - 과제 07/28 (1)
#
# 웹문서에서 빅데이터에 대한 의미있는 정보로 구성된 데이터프레임을 출력하세요.
# (title, link, description)

# %%
import os
import sys
import urllib.request
client_id = "Jj0OXLwhiIThZiPeurcm"
client_secret = "Z34Uu4mSeJ"

query = urllib.parse.quote("빅데이터")
url = 'https://openapi.naver.com/v1/search/webkr.json?query='+query # json 결과
# url = "https://openapi.naver.com/v1/search/webkr.json?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
    
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
df = pd.read_json(response_body.decode('utf-8'))
df
# Out:
# {
# 	"lastBuildDate":"Fri, 29 Jul 2022 08:50:12 +0900",
# 	"total":38809053,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>빅 데이터<\/b> 프로세싱 - 나무위키",
# 			"link":"https:\/\/namu.wiki\/w\/%EB%B9%85%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%ED%94%84%EB%A1%9C%EC%84%B8%EC%8B%B1",
# 			"description":"Big data processing 디지털 시대에서 폭증하는 '방대한 양의 <b>데이터<\/b>(big data)'를 관리하고 분석해서 유용한 정보로 사용하는 기술."
# 		},
# 		{
# 			"title":"<b>빅데이터<\/b>란? | 고급 <b>빅데이터<\/b> 분석 | SAP Insights",
# 			"link":"https:\/\/www.sap.com\/korea\/insights\/what-is-big-data.html",
# 			"description":"비즈니스에 대한 360도 통찰을 제공하고 디지털 노이즈 속에 숨은 성장 기회를 찾도록 돕는 <b>빅데이터<\/b> 솔루션을 만나보세요."
# 		},
# 		{
# 			"title":"<b>빅 데이터<\/b>란 무엇입니까? | Oracle 대한민국",
# 			"link":"https:\/\/www.oracle.com\/kr\/big-data\/what-is-big-data\/",
# 			"description":"<b>빅데이터<\/b>는 특히 새로운 <b>데이터<\/b> 소스에서 나온 더 크고 더 복잡한 <b>데이터<\/b> 세트입니다. <b>빅데이터<\/b>의 이점, 과제 및 모범 사례 외에도 정의 및 역사에 대해 알아보세요."
# 		},
# 		{
# ...

# %%
df['items'][0]['title']
df['items'][0]['link']
df['items'][0]['description']
# Out:
# "Big data processing 디지털 시대에서 폭증하는 '방대한 양의 <b>데이터</b>(big data)'를 관리하고 분석해서 유용한 정보로 사용하는 기술."

# %%
df['items']
# Out:
# 0    {'title': '<b>빅 데이터</b> 프로세싱 - 나무위키', 'link': ...
# 1    {'title': '<b>빅데이터</b>란? | 고급 <b>빅데이터</b> 분석 |...
# 2    {'title': '<b>빅 데이터</b>란 무엇입니까? | Oracle 대한민국'...
# 3    {'title': '<b>빅데이터</b>(big data) 이해 - 정의, 분석, ...
# 4    {'title': '네이버 <b>데이터</b>랩', 'link': 'https://...
# 5    {'title': '<b>빅데이터</b> - BC카드', 'link': 'https...
# 6    {'title': '트라이빅 소개 &lt; 서비스 안내 : KOTRA 무역투자<b>...
# 7    {'title': '국가기술 <b>빅데이터</b> 분석기사 - <b>데이터</b>자...
# 8    {'title': '<b>빅데이터</b>의 이해 - 글이 작품이 되는 공간, 브런치...
# 9    {'title': '미디어백과: <b>빅데이터</b> - 네이버 지식백과', 'li...
# Name: items, dtype: object

# %%
import json
import re
dic_data = json.loads(response_body.decode('utf-8'))
a = dic_data['items']

df1 = pd.DataFrame(a)
df1
# Out:
#                                                title  \
# 0                           <b>빅 데이터</b> 프로세싱 - 나무위키
# 1   <b>빅데이터</b>란? | 고급 <b>빅데이터</b> 분석 | SAP Insights
# 2                 <b>빅 데이터</b>란 무엇입니까? | Oracle 대한민국
# 3   <b>빅데이터</b>(big data) 이해 - 정의, 분석, 기술, 특징, 사례 연구
# 4                                    네이버 <b>데이터</b>랩
# 5                                 <b>빅데이터</b> - BC카드
# 6  트라이빅 소개 &lt; 서비스 안내 : KOTRA 무역투자<b>빅데이터</b> - ...
# 7             국가기술 <b>빅데이터</b> 분석기사 - <b>데이터</b>자격시험
# 8                <b>빅데이터</b>의 이해 - 글이 작품이 되는 공간, 브런치
# 9                      미디어백과: <b>빅데이터</b> - 네이버 지식백과
#
#                                                 link  \
# 0  https://namu.wiki/w/%EB%B9%85%20%EB%8D%B0%EC%9...
# 1  https://www.sap.com/korea/insights/what-is-big...
# 2  https://www.oracle.com/kr/big-data/what-is-big...
# 3          https://www.redhat.com/ko/topics/big-data
# 4                         https://datalab.naver.com/
# 5  https://www.bccard.com/card/html/company/kr/bi...
# ...

# %%
df2 = df.drop('items', axis=1) # 처음 뽑은 df표 items 열 삭제
df2
# Out:
#                      lastBuildDate     total  start  display
# 0  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 1  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 2  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 3  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 4  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 5  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 6  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 7  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 8  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 9  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10

# %%
df3 = df2.join(df1)
df3 # items 열 삭제후 안에서 뽑은 정보들 붙여줌
# Out:
#                      lastBuildDate     total  start  display  \
# 0  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 1  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 2  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 3  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 4  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 5  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 6  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 7  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 8  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
# 9  Thu, 28 Jul 2022 20:18:25 +0900  38520891      1       10
#
#                                                title  \
# 0                           <b>빅 데이터</b> 프로세싱 - 나무위키
# 1   <b>빅데이터</b>란? | 고급 <b>빅데이터</b> 분석 | SAP Insights
# 2                 <b>빅 데이터</b>란 무엇입니까? | Oracle 대한민국
# 3   <b>빅데이터</b>(big data) 이해 - 정의, 분석, 기술, 특징, 사례 연구
# ...

# %% [markdown]
# - 과제 07/28 (2)
#
# 뉴스, 영화, 쇼핑, 지식in, 카페글에서 적합한 주제에 대한 데이터를 가져와 데이터프레임으로 출력하세요.

# %%
import os
import sys
import urllib.request
import warnings
warnings.filterwarnings('ignore')


client_id = "Jj0OXLwhiIThZiPeurcm"
client_secret = "Z34Uu4mSeJ"

query = urllib.parse.quote(input("검색"))
url = 'https://openapi.naver.com/v1/search/kin.json?query='+ query   # 지식인 주소, json형식
# url = f"https://openapi.naver.com/v1/search/webkr.xml?query={query}&display=10&start=1"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
    
import pandas as pd
df = pd.read_json(response_body.decode('utf-8'))
df
# Out:
# 검색빅데이터 분석기사
# {
# 	"lastBuildDate":"Fri, 29 Jul 2022 09:23:22 +0900",
# 	"total":15236,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>빅데이터 분석기사<\/b>",
# 			"link":"https:\/\/kin.naver.com\/qna\/detail.naver?d1id=4&dirId=40608&docId=420897183&qb=67mF642w7J207YSwIOu2hOyEneq4sOyCrA==&enc=utf8&section=kin.qna&rank=1&search_sort=0&spq=0",
# 			"description":"<b>빅데이터 분석기사<\/b>가 되기 위해서는 아무나 될 수가 없다고 들었습니다 되기 위해서 어떤 조건을 충족해야 하나요? 무슨 전공 무슨 경력 등등을 쌓아야 한다고 들어서요! 알려주세요!  안녕하세요 질문자님! 질문자님의 답변에 수기로... "
# 		},
# 		{
# 			"title":"<b>빅데이터 분석기사<\/b> 전공관련",
# 			"link":"https:\/\/kin.naver.com\/qna\/detail.naver?d1id=1&dirId=111&docId=401859262&qb=67mF642w7J207YSwIOu2hOyEneq4sOyCrA==&enc=utf8&section=kin.qna&rank=2&search_sort=0&spq=0",
# 			"description":"... 아무리 찾아봐도 정보가 없어서요. <b>빅데이터분석기사<\/b>는 전공, 비전공 제한이 없어요. 모든 학과가 응시가 가능한 기사 자격증입니다. 따라서 4년제 사진학과 졸업하셨으면 무조건 <b>빅데이터분석기사<\/b>에 응시할 수 있습니다. "
# 		},
# 		{
# 			"title":"<b>빅데이터분석기사<\/b> 해볼까요?",
# ...

# %% [markdown]
# - 과제 07/28 (3)
#
# 아래사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요
# * https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
# * 개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)
# * New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
# * 기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
# * 서울, 토쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
#   - cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
#   - 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
#   - 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# * json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)

# %% [markdown]
# https://openweathermap.org/api

# %%
'''
+ 도시 = Seoul
| 날씨 = broken clouds
| 최저 기온 = -1.0 2
| 최고 기온 = 2.0 2
| 습도 = 74
| 기압 = 1023
| 풍속 = 0.5
'''

# %% [markdown]
# ## 공공데이터 api

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json
import warnings
warnings.filterwarnings('ignore')

skey = 'uGamiWlbz5vqbmJXOUBORkCToFu5YdGGNHXDnA8tcyfdnldCmSBn3o%2F7PyA06mG1wUlUyiFlxEyRQkckNJ7qoQ%3D%3D'
res_id = 'storezone'
stype = 'json'    # type은 예약어니깐 쓰면안됨

url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&'+ urlencode({quote_plus('key'):'9174'})
query = url + params
print(query)

request = Request(query)
# response = requests.get(url, params=params)
# print(response.content)
request.get_method = lambda : 'GET'
response_body = urlopen(request).read()
# print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
items = response_dict['body']['items']

df = pd.DataFrame(items)
df
# Out:
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?ServiceKey=uGamiWlbz5vqbmJXOUBORkCToFu5YdGGNHXDnA8tcyfdnldCmSBn3o%2F7PyA06mG1wUlUyiFlxEyRQkckNJ7qoQ%3D%3D&type=json&resId=storezone&key=9174
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9174        인사동       11    서울특별시    11110      종로구    226875        21
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((126.986059148338 37.5765234907...  2021-06-30

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

def baro_api(skey,res_id,encode):
    
    stype = 'json'
    url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
    params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&{encode}'
    query = url + params
    
    request = Request(query)
    request.get_method = lambda:'GET'
    response_body = urlopen(request).read()
    
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['body']['items']
    df = pd.DataFrame(items)
    return df

# %% [markdown]
# ##  상권조회

# %% [markdown]
# ####  지정 상권조회

# %%
skey = 'uGamiWlbz5vqbmJXOUBORkCToFu5YdGGNHXDnA8tcyfdnldCmSBn3o%2F7PyA06mG1wUlUyiFlxEyRQkckNJ7qoQ%3D%3D'
res_id = 'storezone'
encode = urlencode({quote_plus('key'):'9193'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30

# %% [markdown]
# ####  반경내 상권조회

# %%
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone&catId=radius&radius=500&cx=127.004528&cy=37.567538&ServiceKey=서비스인증키

encode = urlencode({quote_plus('catId'):'radius',quote_plus('radius'):'500',
                   quote_plus('cx'):'127.004528',quote_plus('cy'):'37.567538'})

baro_api(skey, res_id, encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9170     동대문시장_1       11    서울특별시    11110      종로구     75046        13
# 1    9180     종로5가역_1       11    서울특별시    11110      종로구     44881         9
# 2    9192     동대문시장_2       11    서울특별시    11140       중구     60995        18
# 3    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
# 4    9206      을지로4가역       11    서울특별시    11140       중구     81565         9
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00616674831 37.57097429301...  2021-06-30
# 1  MULTIPOLYGON (((127.001579474423 37.5708212220...  2021-06-30
# 2  MULTIPOLYGON (((127.006693001676 37.5694470928...  2021-06-30
# 3  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30
# 4  MULTIPOLYGON (((126.998050690253 37.5686092455...  2021-06-30

# %%
encode = urlencode({quote_plus('catId'):'radius', quote_plus('radius'):'500',
                   quote_plus('cx'):'127.004528', quote_plus('cy'):'37.567538'})

baro_api(skey,res_id,encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9170     동대문시장_1       11    서울특별시    11110      종로구     75046        13
# 1    9180     종로5가역_1       11    서울특별시    11110      종로구     44881         9
# 2    9192     동대문시장_2       11    서울특별시    11140       중구     60995        18
# 3    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
# 4    9206      을지로4가역       11    서울특별시    11140       중구     81565         9
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00616674831 37.57097429301...  2021-06-30
# 1  MULTIPOLYGON (((127.001579474423 37.5708212220...  2021-06-30
# 2  MULTIPOLYGON (((127.006693001676 37.5694470928...  2021-06-30
# 3  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30
# 4  MULTIPOLYGON (((126.998050690253 37.5686092455...  2021-06-30

# %% [markdown]
# - 과제 07/28 (4)

# %% [markdown]
# ####  사각형내 상권조회

# %%
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone
#     &catId=rectangle&minx=126.978020&miny=37.557825&maxx=126.987732&
#     maxy=37.562022&ServiceKey=서비스인증키
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

encode = urlencode({quote_plus('catId'):'rectangle', quote_plus('minx'):'126.978020',
                   quote_plus('miny'):'37.557825', quote_plus('maxx'):'126.987732',
                   quote_plus('maxy'):'37.562022',})

baro_api(skey,res_id,encode)
# Out:
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9191      남대문시장       11    서울특별시    11140       중구    111020        27
# 1    9196        명동역       11    서울특별시    11140       중구     96649        28
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((126.976451547074 37.5576325944...  2021-06-30
# 1  MULTIPOLYGON (((126.983476244148 37.5605598377...  2021-06-30

# %% [markdown]
# #### 행정단위 상권조회

# %%
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone
#     &catId=dong&divId=adongCd&key=1168069000&ServiceKey=서비스인증키


encode = urlencode({quote_plus('catId'):'dong', quote_plus('divId'):'adongCd',
                   quote_plus('key'):'1168069000'})

baro_api(skey,res_id,encode)
# Out:
#    trarNo mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9324      포이사거리       11    서울특별시    11680      강남구     14033        33
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.044811833677 37.4781705036...  2021-06-30

# %% [markdown]
# ##  상가업소 조회

# %% [markdown]
# #### 행정동 단위 상가업소 조회

# %%
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=store&catId=dong&divId=ctprvnCd&key=11&ServiceKey=서비스인증키

res_id = 'store'
encode = urlencode({quote_plus('catId'):'dong',quote_plus('divId'):'ctprvnCd',quote_plus('key'):'11'})


baro_api(skey, res_id, encode)
# Out:
#      bizesId     bizesNm  brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10001387      이음스튜디오                  D         소매        D18
# 1   10004623      이철헤어커커    상계역점          F      생활서비스        F01
# 2   10016187        일조산업                  D         소매        D07
# 3   10030788      장안순대국밥                  Q         음식        Q10
# 4   10031349         장어야    동자동점          Q         음식        Q01
# 5   10031436        장어천국                  Q         음식        Q01
# 6   10034303        재건공조                  D         소매        D07
# 7   10034977        재진패션                  D         소매        D05
# 8   10038561   전자랜드프라이스킹     은평점          D         소매        D12
# 9   10041487         정관장   서대문역점          D         소매        D03
# 10  10041503         정관장   남부법원점          D         소매        D10
# 11  10050747       제시카키친  이대하늬솔점          Q         음식        Q06
# 12  10056742      제일전기조명                  D         소매        D07
# ...
