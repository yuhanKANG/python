# %%
import numpy as np
import pandas as pd
from matplotlib import font_manager, rc # 한글넣기
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력하게 해주는것
font_path = '../../visualization/dataset/malgun.ttf' # 해당파일 visualization > dataset에 있음
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)

# 데이터산업 시장규모
df1 = pd.read_csv('./data/data1.csv', encoding='cp949')
df1
# Out:
#                 데이터산업별(1)    2015    2016    2017    2018    2019    2020  \
# 0                      전체  133555  137547  143530  155684  168582  200024
# 1  데이터 처리 및 관리 솔루션 개발·공급업   14124   15720   16457   18617   20805   25133
# 2       데이터 구축 및 컨설팅 서비스업   55280   55850   58894   61290   65412   76999
# 3        데이터 판매 및 제공 서비스업   64151   65977   68179   75778   82364   97891
#
#    2021 e)
# 0   230972
# 1    30566
# 2    86335
# 3   114071

# %%
df1.columns = ['데이터산업별','2015년','2016년','2017년','2018년','2019년','2020년','2021년']
years = ['2015년','2016년','2017년','2018년','2019년','2020년','2021년']
df1
# Out:
#                    데이터산업별   2015년   2016년   2017년   2018년   2019년   2020년  \
# 0                      전체  133555  137547  143530  155684  168582  200024
# 1  데이터 처리 및 관리 솔루션 개발·공급업   14124   15720   16457   18617   20805   25133
# 2       데이터 구축 및 컨설팅 서비스업   55280   55850   58894   61290   65412   76999
# 3        데이터 판매 및 제공 서비스업   64151   65977   68179   75778   82364   97891
#
#     2021년
# 0  230972
# 1   30566
# 2   86335
# 3  114071

# %%
# x = np.arange(7)

# values = df1.loc[[0]]
# values
# plt.bar(x, values)

# plt.xticks(x, years)
# plt.show()

df1.loc[[0]].plot(kind = 'bar', width =5)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
# 산업별 인력 현황(비중)
# 데이터 직무 전체 인력 현황
df2 = pd.read_csv('./data/data2.csv', encoding='cp949')
df2
# Out:
#                 데이터산업별(1)  데이터직무별(1)     2015     2016     2017     2018  \
# 0               데이터산업별(1)  데이터직무별(1)  인력수 (명)  인력수 (명)  인력수 (명)  인력수 (명)
# 1                      전체         전체    70338    73256    77105    82623
# 2  데이터 처리 및 관리 솔루션 개발·공급업         전체     8886     9272    10291    11541
# 3       데이터 구축 및 컨설팅 서비스업         전체    34323    35404    37516    40197
# 4        데이터 판매 및 제공 서비스업         전체    27129    28580    29298    30885
#
#       2019     2020     2021
# 0  인력수 (명)  인력수 (명)  인력수 (명)
# 1    89058   101967   122431
# 2    13467    17273    22124
# 3    42979    48644    58733
# 4    32611    36050    41574

# %%
import pandas as pd
# 직무별 인력 수요
df3 = pd.read_csv('./data/data3.csv', encoding='cp949')
df3
# Out:
#     데이터직무별(1)   2016   2017  2018  2019  2020
# 0   데이터직무별(1)     전체     전체    전체    전체    전체
# 1          평균    7.9    8.2  10.4  10.7   9.8
# 2    데이터 아키텍트      -      -  12.8  13.2  11.1
# 3     데이터 개발자    6.3    6.4   9.3   9.7   9.4
# 4    데이터 엔지니어    7.9    8.2   9.6   9.5   9.3
# 5     데이터 분석가    7.6    8.0   9.1  10.9   9.9
# 6  데이터베이스 관리자      -      -   6.9   7.9   6.6
# 7     데이터 과학자  100.0  100.0  51.4  44.9  30.4
# 8    데이터 컨설턴트   31.6   32.1  19.4  19.5  17.7
# 9     데이터 기획자    3.7    4.6   7.9   7.4   5.8

# %%
import pandas as pd
# 데이터산업의 직무별 인력 부족률
df4 = pd.read_csv('./data/data4.csv', encoding='cp949')
df4
# Out:
#     데이터직무별(1)  2016  2017  2018  2019  2020
# 0   데이터직무별(1)    전체    전체    전체    전체    전체
# 1          평균  17.8  17.9  32.7  25.4  26.6
# 2    데이터 아키텍트     -     -  40.1   4.4   9.4
# 3     데이터 개발자  27.0  26.1  35.1  26.7  24.5
# 4    데이터 엔지니어   9.3  10.2  28.4   6.4  15.1
# 5     데이터 분석가  33.7  37.3  53.4  57.8  57.6
# 6  데이터베이스 관리자     -     -  19.9   3.1   7.0
# 7     데이터 과학자  13.2  11.0  15.8  53.7  57.5
# 8    데이터 컨설턴트   6.1   7.1  28.2   7.3   3.4
# 9     데이터 기획자  22.6  23.9  30.5  10.6  10.5

# %%
import pandas as pd
# 향후 5년 필요 인력
df5 = pd.read_csv('./data/data5.csv', encoding='cp949')
df5
# Out:
#      데이터직무별(1)           2018             2018.1           2019  \
# 0    데이터직무별(1)             전체                 전체             전체
# 1    데이터직무별(1)  차년도 필요 인력 (명)  향후 5년 내 필요 인력 (명)  차년도 필요 인력 (명)
# 2           전체           1547               9472           3936
# 3     데이터 아키텍트            107                715             29
# 4      데이터 개발자            522               2968           2619
# 5     데이터 엔지니어            143                969            429
# 6      데이터 분석가            273               1559            309
# 7   데이터베이스 관리자            160               1003            107
# 8      데이터 과학자             45                318            148
# 9     데이터 컨설턴트            144                956             73
# 10     데이터 기획자            153                984            223
#
#                2019.1           2020             2020.1           2021  \
# 0                  전체             전체                 전체             전체
# ...
